# %%
from transformer.model import positional_encoding

import matplotlib.pyplot as plt

# %%
pe = positional_encoding(seq_len=5, d=4, N=8)

# %%
plt.figure(figsize=(12, 4))
# plt.imshow(pe[0].numpy(), aspect='auto', cmap='RdBu')
plt.imshow(pe, aspect='auto', cmap='RdBu')
plt.xlabel('Dimension')
plt.ylabel('Position')
plt.colorbar()
plt.title('Positional Encoding Visualization')
plt.draw()
